# %% [markdown]
# <table style="font-size:1.5em;  border: 2px solid black;">
#     <caption>Итого, для p=2,q=2, Du=20, Dv=1 и случайных стартовых данных</caption>
#     <tr>
#         <td>L</td>
#         <td>1</td>
#         <td>2</td>
#         <td>5</td>
#         <td>10</td>
#         <td>20</td>
#         <td>40</td>
#         <td>80</td>
#         <td>160</td>
#     <\tr>
#     <tr>
#         <td>структуры</td>
#         <td>-</td>
#         <td>-</td>
#         <td>0.5</td>
#         <td>1</td>
#         <td>1.5</td>
#         <td>3, 3.5</td>
#         <td>6, 6.5, 7</td>
#         <td>12, 12.5, 13, 13.5, 14, 14.5</td>
#     <\tr>
# </table>

# %% [markdown]
# ### Сырые данные можно взять [здесь](https://drive.google.com/file/d/1gV2WwOm_7djtzjS2nB0CyXF6Ok2hAv35/view?usp=sharing)

# %%
import sys
sys.path.insert(1, '../')

# %%
import pylab as plt
from Drawing.Draw1D import set_defaults_1D

# %%
set_defaults_1D()

# %%
data = [(4.0, 0), (4.020408163265306, 0), (4.040816326530612, 0), (4.061224489795919, 0), (4.081632653061225, 0), (4.1020408163265305, 0), (4.122448979591836, 0), (4.142857142857143, 0), (4.163265306122449, 0), (4.183673469387755, 0), (4.204081632653061, 0), (4.224489795918367, 0), (4.244897959183674, 0), (4.26530612244898, 0), (4.285714285714286, 0), (4.3061224489795915, 0), (4.326530612244898, 0), (4.346938775510204, 0), (4.36734693877551, 0), (4.387755102040816, 0), (4.408163265306122, 0), (4.428571428571429, 0), (4.448979591836735, 0), (4.469387755102041, 0), (4.489795918367347, 0), (4.510204081632653, 0), (4.530612244897959, 0), (4.551020408163265, 0.0), (4.571428571428571, 0.0), (4.591836734693878, 0.0), (4.612244897959184, 0.0), (4.63265306122449, 0.0), (4.653061224489796, 0.0), (4.673469387755102, 0.0), (4.6938775510204085, 0.0), (4.714285714285714, 0.0), (4.73469387755102, 0.0), (4.755102040816326, 0.0), (4.775510204081632, 0.0), (4.795918367346939, 0.0), (4.816326530612245, 0.0), (4.836734693877551, 0.0), (4.857142857142857, 0.0), (4.877551020408164, 0.0), (4.8979591836734695, 0.0), (4.918367346938775, 0.0), (4.938775510204081, 0.0), (4.959183673469388, 0.0), (4.979591836734694, 0.0), (5.0, 0.0)]
ax = plt.gca()
for d in data:
    ax.scatter(d[0],1,c='g' if isinstance(d[1], int) else 'b',s=100)
ax.set_xticklabels(['', 4.0,4.2,4.4,4.6,4.8,'L'])
plt.title('К чему сходится половинка косинуса.\nЗелёное - гомогенно, синее - полупик\nГраница ~4.551')
plt.show()

# %%
data = [(9.0, 0), (9.026315789473685, 0), (9.052631578947368, 0), (9.078947368421053, 0), (9.105263157894736, 1.0), (9.131578947368421, 1.0), (9.157894736842104, 1.0), (9.18421052631579, 1.0), (9.210526315789474, 1.0), (9.236842105263158, 1.0), (9.263157894736842, 1.0), (9.289473684210526, 1.0), (9.31578947368421, 1.0), (9.342105263157894, 1.0), (9.368421052631579, 1.0), (9.394736842105264, 1.0), (9.421052631578947, 1.0), (9.447368421052632, 1.0), (9.473684210526315, 1.0), (9.5, 1.0)]
ax = plt.gca()
for d in data:
    ax.scatter(d[0],1,c='g' if d[1] == 0 else 'r',s=100)
ax.set_xticklabels(['', 9.0,9.1,9.2,9.3,9.4,'L'])
plt.title('К чему сходится однопиковый косинус.\nЗелёное - гомогенно, красное - 1-пик')
plt.show()

# %%
data = [(5.0, 0.0),  (5.1022727272727275, 0.0),  (5.204545454545454, 0.0),  (5.306818181818182, 0.0),  (5.409090909090909, 0.0),  (5.511363636363637, 0.0),  (5.613636363636363, 0.0),  (5.715909090909091, 0.0),  (5.818181818181818, 0.0),  (5.920454545454546, 0.0),  (6.0227272727272725, 0.0),  (6.125, 0.0),  (6.2272727272727275, 0.0),  (6.329545454545456, 0.0),  (6.431818181818182, 0.0),  (6.534090909090909, 0.0),  (6.636363636363638, 0.0),  (6.738636363636363, 0.0),  (6.840909090909091, 0.0),  (6.943181818181819, 0.0),  (7.045454545454545, 0.0),  (7.147727272727273, 0.0),  (7.249999999999999, 0.0),  (7.352272727272728, 0.0),  (7.454545454545455, 0.0),  (7.556818181818182, 0.0),  (7.65909090909091, 0.0),  (7.761363636363637, 0.0),  (7.863636363636363, 0.0),  (7.965909090909092, 0.0),  (8.068181818181818, 0.0),  (8.170454545454547, 0.0),  (8.272727272727273, 0.0),  (8.375, 0.0),  (8.477272727272727, 0),  (8.579545454545455, 0),  (8.681818181818182, 0),  (8.78409090909091, 0),  (8.886363636363637, 0),  (8.988636363636363, 0),  (9.09090909090909, 0),  (9.193181818181818, 1.0),  (9.295454545454547, 1.0),  (9.397727272727273, 1.0),  (9.5, 1.0)]
c = {0.0: 'b', 1.0: 'r'}
ax = plt.gca()
for d in data:
    ax.scatter(d[0],1,c='g' if isinstance(d[1], int) else c[d[1]],s=100)
ax.set_xticklabels(['', 5,6,7,8,'L'])
plt.title('К чему сходится случайность.\nСинее - полупик, зелёное - гомогенно, красное - 1-пик')
plt.show()

# %%
data = [(13.0, 1.0), (13.157894736842104, 1.0), (13.31578947368421, 1.0), (13.473684210526315, 1.0), (13.631578947368423, 1.0), (13.789473684210526, 1.0), (13.947368421052634, 1.0), (14.105263157894738, 1.0), (14.26315789473684, 1.0), (14.421052631578949, 1.0), (14.578947368421053, 1.0), (14.736842105263156, 1.0), (14.894736842105264, 1.5), (15.052631578947368, 1.5), (15.21052631578947, 1.5), (15.368421052631579, 1.5), (15.526315789473685, 1.5), (15.68421052631579, 1.5), (15.842105263157894, 1.5), (16.0, 1.5)]
c = {1.0: 'r', 1.5: 'm'}
ax = plt.gca()
for d in data:
    ax.scatter(d[0],1,c=c[d[1]],s=200)
ax.set_xticklabels(['', 13,13.5,14,14.5,15,15.5,'L'])
plt.title('К чему сходится 1.5косинус.\nКрасное - 1-пик, фиолетовое - 1.5 пика')
plt.show()

# %%
4.551*3
# Out:
# 13.653
